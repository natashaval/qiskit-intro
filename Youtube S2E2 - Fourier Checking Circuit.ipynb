# %%
import qiskit.quantum_info as qi
from qiskit.circuit.library import FourierChecking
from qiskit.visualization import plot_histogram

f = [1, -1, -1, -1]
#g = [1, 1, -1, -1]
g = [5, -1, 6, 2]
circ = FourierChecking(f=f, g=g)
circ.draw('mpl')
# Out:
# ---------------------------------------------------------------------------
# QiskitError                               Traceback (most recent call last)
# /var/folders/7j/_yrz2d6s5y9dqjwr_2s9vvq00000gn/T/ipykernel_2470/447556696.py in <module>
#       6 #g = [1, 1, -1, -1]
#       7 g = [5, -1, 6, 2]
# ----> 8 circ = FourierChecking(f=f, g=g)
#       9 circ.draw('mpl')
#
# ~/Library/Python/3.8/lib/python/site-packages/qiskit/circuit/library/fourier_checking.py in __init__(self, f, g)
#      91         circuit.h(circuit.qubits)
#      92
# ---> 93         circuit.diagonal(g, circuit.qubits)
#      94
#      95         circuit.h(circuit.qubits)
#
# ~/Library/Python/3.8/lib/python/site-packages/qiskit/extensions/quantum_initializer/diagonal.py in diagonal(self, diag, qubit)
#     152             "The number of diagonal entries does not correspond to" " the number of qubits."
#     153         )
# --> 154     return self.append(DiagonalGate(diag), qubit)
#     155
#     156
#
# ~/Library/Python/3.8/lib/python/site-packages/qiskit/extensions/quantum_initializer/diagonal.py in __init__(self, diag)
#      57                 ) from ex
#      58             if not np.abs(z) - 1 < _EPS:
# ---> 59                 raise QiskitError("A diagonal entry has not absolute value one.")
#      60         # Create new gate.
#      61         super().__init__("diagonal", int(num_action_qubits), diag)
#
# QiskitError: 'A diagonal entry has not absolute value one.'

# %%
zero = qi.Statevector.from_label('00')
sv = zero.evolve(circ)
probs = sv.probabilities_dict()
plot_histogram(probs)
