# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_state_qsphere


# Single-qubit state
mycircuit = QuantumCircuit(1)
mycircuit.x(0)
mycircuit.draw('mpl')

# %%
sv = Statevector.from_label('0')
sv.data
# Out:
# array([1.+0.j, 0.+0.j])

# %%
plot_state_qsphere(sv)
# Out:
# /usr/local/lib/python3.9/site-packages/qiskit/visualization/bloch.py:69: MatplotlibDeprecationWarning:
# The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
#   x_s, y_s, _ = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)

# %%
new_sv = sv.evolve(mycircuit)
print(new_sv)
plot_state_qsphere(new_sv)
# Out:
# Statevector([0.+0.j, 1.+0.j],
#             dims=(2,))
# /usr/local/lib/python3.9/site-packages/qiskit/visualization/bloch.py:69: MatplotlibDeprecationWarning:
# The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
#   x_s, y_s, _ = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)

# %%
# Multi-qubit states

sv = Statevector.from_label('00')
plot_state_qsphere(sv)
# Out:
# /usr/local/lib/python3.9/site-packages/qiskit/visualization/bloch.py:69: MatplotlibDeprecationWarning:
# The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
#   x_s, y_s, _ = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)

# %%
multiCircuit = QuantumCircuit(2)
multiCircuit.h(0)
multiCircuit.cx(0,1)
multiCircuit.draw('mpl')

# %%
multi_sv = sv.evolve(multiCircuit)
print(multi_sv)
plot_state_qsphere(multi_sv)
# Out:
# Statevector([0.70710678+0.j, 0.        +0.j, 0.        +0.j,
#              0.70710678+0.j],
#             dims=(2, 2))
# /usr/local/lib/python3.9/site-packages/qiskit/visualization/bloch.py:69: MatplotlibDeprecationWarning:
# The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
#   x_s, y_s, _ = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)

# %%
counts = multi_sv.sample_counts(shots = 1000)
from qiskit.visualization import plot_histogram
plot_histogram(counts)

# %%
# Ungraded Exercise 1 (|01> + |10>)/sqrt(2)

sv1 = Statevector.from_label('10') # |01> read from right to left
exCircuit = QuantumCircuit(2)
exCircuit.h(0)
exCircuit.cx(0,1)
exCircuit.draw('mpl')

new_sv1 = sv1.evolve(exCircuit)
print(new_sv1)
plot_state_qsphere(new_sv1)
# Out:
# Statevector([0.        +0.j, 0.70710678+0.j, 0.70710678+0.j,
#              0.        +0.j],
#             dims=(2, 2))
# /usr/local/lib/python3.9/site-packages/qiskit/visualization/bloch.py:69: MatplotlibDeprecationWarning:
# The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
#   x_s, y_s, _ = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)

# %%
# Ungraded Exercise 2 (|01> - |10>)/sqrt(2)

sv2 = Statevector.from_label('11')
new_sv2 = sv2.evolve(exCircuit)
print(new_sv2)
plot_state_qsphere(new_sv2)
# Out:
# Statevector([ 0.        +0.j, -0.70710678+0.j,  0.70710678+0.j,
#               0.        +0.j],
#             dims=(2, 2))
# /usr/local/lib/python3.9/site-packages/qiskit/visualization/bloch.py:69: MatplotlibDeprecationWarning:
# The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
#   x_s, y_s, _ = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)
